# %%
# pip install pandas

# %%
import pandas as pd
import json

# %%
data = pd.read_csv('logv.csv',names='uno')

# %%
data2 = list(data['u'])

# %%
da = []
for i in range(0,len(data2)):
    d = data2[i].split('.gz:')
    da.append(json.loads((d[1])))

# %%
data = pd.DataFrame(da)

# %%
data[['event']].iloc[42].to_csv('hola.txt')

# %%
valor = data[['event']].values.tolist()

# %%
for i in range(0,len(valor)):
    print(i)
    estado = (isinstance(valor[i][0], str))
    print(estado)
    print(valor[i][0])
    if estado == True:
        print(type(json.loads(valor[i][0])))
# Out:
# 0
# False
# {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC', 'user_id': 258, 'mode': 'honor'}
# 1
# True
# {"POST": {}, "GET": {}}
# <class 'dict'>
# 2
# True
# {"POST": {}, "GET": {}}
# <class 'dict'>
# 3
# True
# {"POST": {}, "GET": {}}
# <class 'dict'>
# 4
# True
# {"POST": {}, "GET": {}}
# <class 'dict'>
# 5
# True
# {"POST": {}, "GET": {}}
# <class 'dict'>
# 6
# True
# {"POST": {}, "GET": {}}
# <class 'dict'>
# 7
# True
# {"POST": {}, "GET": {}}
# <class 'dict'>
# 8
# True
# {"POST": {}, "GET": {}}
# <class 'dict'>
# 9
# True
# {"POST": {}, "GET": {}}
# <class 'dict'>
# 10
# True
# {"POST": {}, "GET": {}}
# <class 'dict'>
# 11
# True
# {"POST": {}, "GET": {}}
# <class 'dict'>
# 12
# True
# {"POST": {}, "GET": {}}
# <class 'dict'>
# 13
# True
# {"POST": {}, "GET": {}}
# <class 'dict'>
# 14
# True
# {"POST": {}, "GET": {}}
# <class 'dict'>
# 15
# True
# {"POST": {}, "GET": {}}
# <class 'dict'>
# 16
# True
# {"POST": {}, "GET": {}}
# <class 'dict'>
# 17
# True
# ...

# %%
for i in range(0,len(valor)):
    print(i)
    estado = (isinstance(valor[i][0], str))
    print(estado)
    print(valor[i][0])
# Out:
# 0
# False
# {'course_id': 'course-v1:UTPL+EFHE-Ed7+2017_DIC', 'user_id': 258, 'mode': 'honor'}
# 1
# True
# {"POST": {}, "GET": {}}
# 2
# True
# {"POST": {}, "GET": {}}
# 3
# True
# {"POST": {}, "GET": {}}
# 4
# True
# {"POST": {}, "GET": {}}
# 5
# True
# {"POST": {}, "GET": {}}
# 6
# True
# {"POST": {}, "GET": {}}
# 7
# True
# {"POST": {}, "GET": {}}
# 8
# True
# {"POST": {}, "GET": {}}
# 9
# True
# {"POST": {}, "GET": {}}
# 10
# True
# {"POST": {}, "GET": {}}
# 11
# True
# {"POST": {}, "GET": {}}
# 12
# True
# {"POST": {}, "GET": {}}
# 13
# True
# {"POST": {}, "GET": {}}
# 14
# True
# {"POST": {}, "GET": {}}
# 15
# True
# {"POST": {}, "GET": {}}
# 16
# True
# {"POST": {}, "GET": {}}
# 17
# True
# {"POST": {}, "GET": {}}
# 18
# True
# {"POST": {}, "GET": {}}
# 19
# True
# {"POST": {}, "GET": {}}
# 20
# True
# {"POST": {}, "GET": {}}
# 21
# True
# {"POST": {}, "GET": {}}
# 22
# True
# {"POST": {}, "GET": {}}
# 23
# True
# {"POST": {}, "GET": {}}
# 24
# True
# {"POST": {}, "GET": {}}
# ...
